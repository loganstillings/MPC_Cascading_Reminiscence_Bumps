# %%
import matplotlib.pyplot as plt

fig1 = plt.figure(figsize=(10, 12))


x_values = [1,2,3,4] # years
y_values = [1,2,3,4] # average

y_error = [1,0.5,0.75,0.25] # standard deviation

plt.errorbar(x_values, y_values,  yerr=y_error ,fmt='o', markersize=8,capsize=20)

plt.show()
